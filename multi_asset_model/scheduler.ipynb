# %%
# from evaluation_model import evaluate
from train_model import trainer
from evaluation_model import evaluate

# %%
# asset_list = ['AEP', 'C','CL','F','HAL','HON','IP','LAZ','ORCL','PG']
asset_list = ['C','CL','F','HAL']
# asset_list = ['LAZ']
model_number = 20
beta = 1e-3 
# beta = 0.03 
note = '4-asset-model-30k paths-no-wealth'
# for i in asset_list: note += (i + ',')
# note = note[:-1]
# for i in range(20):
trainer(model_number, beta, note, asset_list, attempts =4)
# trainer(0, 0.03, 'linear', asset_list, attempts =1)
evaluate(model_number,1,beta,note,asset_list)
# Out:
# Processing : ['C', 'CL', 'F', 'HAL']
# Training Model [1/4]
# /home/br4250/.conda/envs/torch-env/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:240: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch [0/5000], Loss: nan, LR: nan, Average Wealth: nan, Average total costs paid: nan
# Epoch [100/5000], Loss: nan, LR: nan, Average Wealth: nan, Average total costs paid: nan
# Epoch [200/5000], Loss: nan, LR: nan, Average Wealth: nan, Average total costs paid: nan
# ...

# %%
# asset_list = ['C','CL','F','HAL']
# model_number = 12
# note = '4-asset-model-30k paths-no-wealth'
# evaluate(model_number,1,1e-4,note,asset_list)
